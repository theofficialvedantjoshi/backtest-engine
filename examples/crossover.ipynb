# %% [markdown]
# #### Importing Dependencies

# %%
import os
import sys

path = os.path.abspath(os.path.join(".."))
if path not in sys.path:
    sys.path.append(path)
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import yfinance as yf

from backtest import Backtester
from models import HOLD, EntrySignal, ExitSignal

# %% [markdown]
# #### Downloading OHLC data and processing it

# %%
TICKER = "TSLA"
START_DATE = "2015-01-01"
END_DATE = "2025-01-01"

# %%
df = yf.download(TICKER, start=START_DATE, end=END_DATE)

if df is None:
    raise ValueError("Failed to download data from yfinance.")

df.columns = df.columns.get_level_values(0)
# df = df.iloc[2:].reset_index(drop=True)
# df.rename(columns={"Price": "Date"}, inplace=True)
# df.set_index("Date", inplace=True)
df[["Close", "High", "Low", "Open"]] = (
    df[["Close", "High", "Low", "Open"]].astype(float).apply(np.round, args=(4,))
)
df["Volume"] = df["Volume"].astype(int)
df[
    [
        "Entry_Signal",
        "Exit_Signal",
        "Edit_Signal",
    ]
] = HOLD
df[
    [
        "Signal_Volume",
        "Signal_Stop_Loss",
        "Signal_Limit",
    ]
] = 0.0
df["Signal_Volume"] = df["Signal_Volume"].astype(int)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price         Close     High      Low     Open    Volume  Entry_Signal  \
# Date
# 2015-01-02  14.6207  14.8833  14.2173  14.8580  71466000             2
# 2015-01-05  14.0060  14.4333  13.8107  14.3033  80527500             2
# 2015-01-06  14.0853  14.2800  13.6140  14.0040  93928500             2
# 2015-01-07  14.0633  14.3187  13.9853  14.2233  44526000             2
# 2015-01-08  14.0413  14.2533  14.0007  14.1873  51637500             2
#
# Price       Exit_Signal  Edit_Signal  Signal_Volume  Signal_Stop_Loss  \
# Date
# 2015-01-02            2            2              0               0.0
# 2015-01-05            2            2              0               0.0
# 2015-01-06            2            2              0               0.0
# 2015-01-07            2            2              0               0.0
# 2015-01-08            2            2              0               0.0
#
# Price       Signal_Limit
# Date
# 2015-01-02           0.0
# 2015-01-05           0.0
# 2015-01-06           0.0
# 2015-01-07           0.0
# 2015-01-08           0.0

# %%
short_window = 100
long_window = 400
trade_volume = 5
df["short_mavg"] = df["Close"].rolling(window=short_window, min_periods=1).mean()
df["long_mavg"] = df["Close"].rolling(window=long_window, min_periods=1).mean()
df.head()
# Out:
# Price         Close     High      Low     Open    Volume  Entry_Signal  \
# Date
# 2015-01-02  14.6207  14.8833  14.2173  14.8580  71466000             2
# 2015-01-05  14.0060  14.4333  13.8107  14.3033  80527500             2
# 2015-01-06  14.0853  14.2800  13.6140  14.0040  93928500             2
# 2015-01-07  14.0633  14.3187  13.9853  14.2233  44526000             2
# 2015-01-08  14.0413  14.2533  14.0007  14.1873  51637500             2
#
# Price       Exit_Signal  Edit_Signal  Signal_Volume  Signal_Stop_Loss  \
# Date
# 2015-01-02            2            2              0               0.0
# 2015-01-05            2            2              0               0.0
# 2015-01-06            2            2              0               0.0
# 2015-01-07            2            2              0               0.0
# 2015-01-08            2            2              0               0.0
#
# Price       Signal_Limit  short_mavg  long_mavg
# Date
# 2015-01-02           0.0   14.620700  14.620700
# 2015-01-05           0.0   14.313350  14.313350
# 2015-01-06           0.0   14.237333  14.237333
# 2015-01-07           0.0   14.193825  14.193825
# 2015-01-08           0.0   14.163320  14.163320

# %%
longs = (df["short_mavg"] > df["long_mavg"]) & (
    df["short_mavg"].shift(1) <= df["long_mavg"].shift(1)
)
shorts = (df["short_mavg"] < df["long_mavg"]) & (
    df["short_mavg"].shift(1) >= df["long_mavg"].shift(1)
)

df.loc[longs, ["Entry_Signal", "Exit_Signal", "Signal_Volume"]] = [
    EntrySignal.BUY.value,
    ExitSignal.CLOSE_SELL.value,
    trade_volume,
]
df.loc[shorts, ["Entry_Signal", "Exit_Signal", "Signal_Volume"]] = [
    EntrySignal.SELL.value,
    ExitSignal.CLOSE_BUY.value,
    trade_volume,
]
df["Entry_Signal"] = df["Entry_Signal"].shift(1).fillna(HOLD).astype(int)
df["Exit_Signal"] = df["Exit_Signal"].shift(1).fillna(HOLD).astype(int)
df["Signal_Volume"] = df["Signal_Volume"].shift(1).fillna(0).astype(int)

# %%
df.drop(columns=["short_mavg", "long_mavg"], inplace=True)
df.head()
# Out:
# Price         Close     High      Low     Open    Volume  Entry_Signal  \
# Date
# 2015-01-02  14.6207  14.8833  14.2173  14.8580  71466000             2
# 2015-01-05  14.0060  14.4333  13.8107  14.3033  80527500             2
# 2015-01-06  14.0853  14.2800  13.6140  14.0040  93928500             2
# 2015-01-07  14.0633  14.3187  13.9853  14.2233  44526000             2
# 2015-01-08  14.0413  14.2533  14.0007  14.1873  51637500             2
#
# Price       Exit_Signal  Edit_Signal  Signal_Volume  Signal_Stop_Loss  \
# Date
# 2015-01-02            2            2              0               0.0
# 2015-01-05            2            2              0               0.0
# 2015-01-06            2            2              0               0.0
# 2015-01-07            2            2              0               0.0
# 2015-01-08            2            2              0               0.0
#
# Price       Signal_Limit
# Date
# 2015-01-02           0.0
# 2015-01-05           0.0
# 2015-01-06           0.0
# 2015-01-07           0.0
# 2015-01-08           0.0

# %%
starting_balance = 100000.0
currency = "USD"
bt = Backtester(starting_balance=starting_balance, ohlc_data=df, currency=currency)

# %%
bt.run_backtest()
# Out:
# DATA Price
# Close               1.462070e+01
# High                1.488330e+01
# Low                 1.421730e+01
# Open                1.485800e+01
# Volume              7.146600e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-02 00:00:00, dtype: float64
# DATA Price
# Close               1.400600e+01
# High                1.443330e+01
# Low                 1.381070e+01
# Open                1.430330e+01
# Volume              8.052750e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-05 00:00:00, dtype: float64
# DATA Price
# Close               1.408530e+01
# High                1.428000e+01
# Low                 1.361400e+01
# Open                1.400400e+01
# Volume              9.392850e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-06 00:00:00, dtype: float64
# DATA Price
# Close               1.406330e+01
# High                1.431870e+01
# Low                 1.398530e+01
# Open                1.422330e+01
# Volume              4.452600e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-07 00:00:00, dtype: float64
# DATA Price
# Close               1.404130e+01
# High                1.425330e+01
# Low                 1.400070e+01
# Open                1.418730e+01
# Volume              5.163750e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-08 00:00:00, dtype: float64
# DATA Price
# Close               1.377730e+01
# High                1.399870e+01
# Low                 1.366400e+01
# Open                1.392800e+01
# Volume              7.002450e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-09 00:00:00, dtype: float64
# DATA Price
# Close               1.348070e+01
# High                1.363130e+01
# Low                 1.328330e+01
# Open                1.353670e+01
# Volume              8.925450e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-12 00:00:00, dtype: float64
# DATA Price
# Close               1.361670e+01
# High                1.384070e+01
# Low                 1.339400e+01
# Open                1.355470e+01
# Volume              6.715950e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-13 00:00:00, dtype: float64
# DATA Price
# Close               1.284600e+01
# High                1.301330e+01
# Low                 1.233330e+01
# Open                1.238870e+01
# Volume              1.732785e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-14 00:00:00, dtype: float64
# DATA Price
# Close               1.279130e+01
# High                1.305000e+01
# Low                 1.266670e+01
# Open                1.296600e+01
# Volume              7.824750e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-15 00:00:00, dtype: float64
# DATA Price
# Close               1.287130e+01
# High                1.296600e+01
# Low                 1.264330e+01
# Open                1.271330e+01
# Volume              5.404800e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-16 00:00:00, dtype: float64
# DATA Price
# Close               1.279530e+01
# High                1.294130e+01
# Low                 1.246930e+01
# Open                1.292470e+01
# Volume              6.754800e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-20 00:00:00, dtype: float64
# DATA Price
# Close               1.310470e+01
# High                1.324530e+01
# Low                 1.263400e+01
# Open                1.263670e+01
# Volume              6.229500e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-21 00:00:00, dtype: float64
# DATA Price
# Close               1.344130e+01
# High                1.354930e+01
# Low                 1.301330e+01
# Open                1.313330e+01
# Volume              6.175350e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-22 00:00:00, dtype: float64
# DATA Price
# Close               1.341930e+01
# High                1.356670e+01
# Low                 1.322200e+01
# Open                1.335270e+01
# Volume              5.157900e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-23 00:00:00, dtype: float64
# DATA Price
# Close               1.377000e+01
# High                1.390800e+01
# Low                 1.340330e+01
# Open                1.345530e+01
# Volume              4.851750e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-26 00:00:00, dtype: float64
# DATA Price
# Close               1.373200e+01
# High                1.386870e+01
# Low                 1.355330e+01
# Open                1.362800e+01
# Volume              4.171500e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-27 00:00:00, dtype: float64
# DATA Price
# Close               1.329130e+01
# High                1.375800e+01
# Low                 1.322800e+01
# Open                1.374070e+01
# Volume              4.724400e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-28 00:00:00, dtype: float64
# DATA Price
# Close               1.368000e+01
# High                1.373200e+01
# Low                 1.310000e+01
# Open                1.340470e+01
# Volume              5.322150e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-29 00:00:00, dtype: float64
# DATA Price
# Close               1.357330e+01
# High                1.383130e+01
# Low                 1.353330e+01
# Open                1.359730e+01
# Volume              4.510500e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-01-30 00:00:00, dtype: float64
# DATA Price
# Close               1.406270e+01
# High                1.413000e+01
# Low                 1.355330e+01
# Open                1.359800e+01
# Volume              6.223800e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-02 00:00:00, dtype: float64
# DATA Price
# Close               1.455730e+01
# High                1.469130e+01
# Low                 1.408470e+01
# Open                1.421470e+01
# Volume              7.239300e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-03 00:00:00, dtype: float64
# DATA Price
# Close               1.457000e+01
# High                1.476530e+01
# Low                 1.445330e+01
# Open                1.455270e+01
# Volume              4.958100e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-04 00:00:00, dtype: float64
# DATA Price
# Close               1.473270e+01
# High                1.503200e+01
# Low                 1.464270e+01
# Open                1.465870e+01
# Volume              5.284350e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-05 00:00:00, dtype: float64
# DATA Price
# Close               1.449070e+01
# High                1.489330e+01
# Low                 1.443330e+01
# Open                1.480000e+01
# Volume              4.865850e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-06 00:00:00, dtype: float64
# DATA Price
# Close               1.449870e+01
# High                1.452870e+01
# Low                 1.413270e+01
# Open                1.435870e+01
# Volume              5.208600e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-09 00:00:00, dtype: float64
# DATA Price
# Close               1.441930e+01
# High                1.470000e+01
# Low                 1.433330e+01
# Open                1.450330e+01
# Volume              8.085750e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-10 00:00:00, dtype: float64
# DATA Price
# Close               1.418670e+01
# High                1.431600e+01
# Low                 1.381870e+01
# Open                1.414730e+01
# Volume              1.465365e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-11 00:00:00, dtype: float64
# DATA Price
# Close               1.352530e+01
# High                1.353930e+01
# Low                 1.288530e+01
# Open                1.290470e+01
# Volume              2.347440e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-12 00:00:00, dtype: float64
# DATA Price
# Close               1.358470e+01
# High                1.373270e+01
# Low                 1.339400e+01
# Open                1.352670e+01
# Volume              9.286500e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-13 00:00:00, dtype: float64
# DATA Price
# Close               1.362330e+01
# High                1.371330e+01
# Low                 1.343330e+01
# Open                1.371330e+01
# Volume              5.969400e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-17 00:00:00, dtype: float64
# DATA Price
# Close               1.363070e+01
# High                1.374470e+01
# Low                 1.350670e+01
# Open                1.361130e+01
# Volume              4.070400e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-18 00:00:00, dtype: float64
# DATA Price
# Close               1.411400e+01
# High                1.416270e+01
# Low                 1.358330e+01
# Open                1.366670e+01
# Volume              7.731150e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-19 00:00:00, dtype: float64
# DATA Price
# Close               1.447400e+01
# High                1.450670e+01
# Low                 1.398730e+01
# Open                1.405200e+01
# Volume              8.973150e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-20 00:00:00, dtype: float64
# DATA Price
# Close               1.382270e+01
# High                1.454670e+01
# Low                 1.375530e+01
# Open                1.437730e+01
# Volume              1.274970e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-23 00:00:00, dtype: float64
# DATA Price
# Close               1.360730e+01
# High                1.381930e+01
# Low                 1.344670e+01
# Open                1.381930e+01
# Volume              9.905400e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-24 00:00:00, dtype: float64
# DATA Price
# Close               1.358400e+01
# High                1.380930e+01
# Low                 1.350530e+01
# Open                1.366270e+01
# Volume              5.864250e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-25 00:00:00, dtype: float64
# DATA Price
# Close               1.381270e+01
# High                1.407270e+01
# Low                 1.348130e+01
# Open                1.360000e+01
# Volume              9.709350e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-26 00:00:00, dtype: float64
# DATA Price
# Close               1.355600e+01
# High                1.390330e+01
# Low                 1.352000e+01
# Open                1.379330e+01
# Volume              5.823150e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-02-27 00:00:00, dtype: float64
# DATA Price
# Close               1.315530e+01
# High                1.355600e+01
# Low                 1.305530e+01
# Open                1.351330e+01
# Volume              1.188315e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-02 00:00:00, dtype: float64
# DATA Price
# Close               1.330400e+01
# High                1.334930e+01
# Low                 1.302130e+01
# Open                1.312070e+01
# Volume              6.648450e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-03 00:00:00, dtype: float64
# DATA Price
# Close               1.349600e+01
# High                1.350130e+01
# Low                 1.314730e+01
# Open                1.328330e+01
# Volume              6.333000e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-04 00:00:00, dtype: float64
# DATA Price
# Close               1.337530e+01
# High                1.374600e+01
# Low                 1.334330e+01
# Open                1.352330e+01
# Volume              7.315500e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-05 00:00:00, dtype: float64
# DATA Price
# Close               1.292530e+01
# High                1.338330e+01
# Low                 1.281000e+01
# Open                1.328070e+01
# Volume              1.006860e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-06 00:00:00, dtype: float64
# DATA Price
# Close               1.272530e+01
# High                1.296600e+01
# Low                 1.255000e+01
# Open                1.295930e+01
# Volume              1.010505e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-09 00:00:00, dtype: float64
# DATA Price
# Close               1.268800e+01
# High                1.290000e+01
# Low                 1.250670e+01
# Open                1.256400e+01
# Volume              8.369550e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-10 00:00:00, dtype: float64
# DATA Price
# Close               1.291600e+01
# High                1.307870e+01
# Low                 1.273400e+01
# Open                1.274330e+01
# Volume              7.462350e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-11 00:00:00, dtype: float64
# DATA Price
# Close               1.273800e+01
# High                1.296330e+01
# Low                 1.265000e+01
# Open                1.291670e+01
# Volume              6.223950e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-12 00:00:00, dtype: float64
# DATA Price
# Close               1.257870e+01
# High                1.278330e+01
# Low                 1.248800e+01
# Open                1.259670e+01
# Volume              8.151450e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-13 00:00:00, dtype: float64
# DATA Price
# Close               1.304670e+01
# High                1.306070e+01
# Low                 1.265330e+01
# Open                1.280000e+01
# Volume              8.443200e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-16 00:00:00, dtype: float64
# DATA Price
# Close               1.298200e+01
# High                1.324730e+01
# Low                 1.292930e+01
# Open                1.302870e+01
# Volume              7.341150e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-17 00:00:00, dtype: float64
# DATA Price
# Close               1.338070e+01
# High                1.339200e+01
# Low                 1.287400e+01
# Open                1.299730e+01
# Volume              7.231350e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-18 00:00:00, dtype: float64
# DATA Price
# Close               1.304330e+01
# High                1.363930e+01
# Low                 1.296870e+01
# Open                1.346670e+01
# Volume              1.271280e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-19 00:00:00, dtype: float64
# DATA Price
# Close               1.320530e+01
# High                1.326600e+01
# Low                 1.304130e+01
# Open                1.316330e+01
# Volume              6.404250e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-20 00:00:00, dtype: float64
# DATA Price
# Close               1.330870e+01
# High                1.336670e+01
# Low                 1.316470e+01
# Open                1.323330e+01
# Volume              3.947400e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-23 00:00:00, dtype: float64
# DATA Price
# Close               1.344800e+01
# High                1.358600e+01
# Low                 1.331670e+01
# Open                1.343870e+01
# Volume              5.474850e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-24 00:00:00, dtype: float64
# DATA Price
# Close               1.295330e+01
# High                1.323930e+01
# Low                 1.284670e+01
# Open                1.321800e+01
# Volume              8.595600e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-25 00:00:00, dtype: float64
# DATA Price
# Close               1.269400e+01
# High                1.298600e+01
# Low                 1.264670e+01
# Open                1.292800e+01
# Volume              6.192000e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-26 00:00:00, dtype: float64
# DATA Price
# Close               1.233330e+01
# High                1.261930e+01
# Low                 1.209330e+01
# Open                1.260470e+01
# Volume              1.290735e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-27 00:00:00, dtype: float64
# DATA Price
# Close               1.270470e+01
# High                1.281670e+01
# Low                 1.212000e+01
# Open                1.239000e+01
# Volume              1.513425e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-30 00:00:00, dtype: float64
# DATA Price
# Close               1.258470e+01
# High                1.291730e+01
# Low                 1.256070e+01
# Open                1.290200e+01
# Volume              7.539900e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-03-31 00:00:00, dtype: float64
# DATA Price
# Close               1.250600e+01
# High                1.282000e+01
# Low                 1.240330e+01
# Open                1.258000e+01
# Volume              5.691900e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-01 00:00:00, dtype: float64
# DATA Price
# Close               1.273330e+01
# High                1.288200e+01
# Low                 1.266670e+01
# Open                1.268200e+01
# Volume              7.515600e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-02 00:00:00, dtype: float64
# DATA Price
# Close               1.354000e+01
# High                1.385000e+01
# Low                 1.316670e+01
# Open                1.320000e+01
# Volume              1.868370e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-06 00:00:00, dtype: float64
# DATA Price
# Close               1.355000e+01
# High                1.367070e+01
# Low                 1.340930e+01
# Open                1.350070e+01
# Volume              6.521850e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-07 00:00:00, dtype: float64
# DATA Price
# Close               1.384470e+01
# High                1.406000e+01
# Low                 1.372470e+01
# Open                1.388000e+01
# Volume              9.454650e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-08 00:00:00, dtype: float64
# DATA Price
# Close               1.400600e+01
# High                1.402470e+01
# Low                 1.374130e+01
# Open                1.389530e+01
# Volume              5.700300e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-09 00:00:00, dtype: float64
# DATA Price
# Close               1.406000e+01
# High                1.411000e+01
# Low                 1.393330e+01
# Open                1.399000e+01
# Volume              6.101550e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-10 00:00:00, dtype: float64
# DATA Price
# Close               1.398530e+01
# High                1.420000e+01
# Low                 1.393670e+01
# Open                1.402930e+01
# Volume              5.637300e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-13 00:00:00, dtype: float64
# DATA Price
# Close               1.383070e+01
# High                1.396600e+01
# Low                 1.370000e+01
# Open                1.390470e+01
# Volume              4.539000e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-14 00:00:00, dtype: float64
# DATA Price
# Close               1.385530e+01
# High                1.397270e+01
# Low                 1.377330e+01
# Open                1.383070e+01
# Volume              2.928600e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-15 00:00:00, dtype: float64
# DATA Price
# Close               1.378000e+01
# High                1.394470e+01
# Low                 1.375270e+01
# Open                1.384670e+01
# Volume              2.488650e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-16 00:00:00, dtype: float64
# DATA Price
# Close               1.378600e+01
# High                1.379200e+01
# Low                 1.356670e+01
# Open                1.366600e+01
# Volume              3.704850e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-17 00:00:00, dtype: float64
# DATA Price
# Close               1.368470e+01
# High                1.385670e+01
# Low                 1.359000e+01
# Open                1.378530e+01
# Volume              3.838950e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-20 00:00:00, dtype: float64
# DATA Price
# Close               1.396070e+01
# High                1.405000e+01
# Low                 1.362070e+01
# Open                1.372000e+01
# Volume              5.148750e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-21 00:00:00, dtype: float64
# DATA Price
# Close               1.462930e+01
# High                1.479200e+01
# Low                 1.411270e+01
# Open                1.416670e+01
# Volume              1.179450e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-22 00:00:00, dtype: float64
# DATA Price
# Close               1.457330e+01
# High                1.476530e+01
# Low                 1.447670e+01
# Open                1.455130e+01
# Volume              6.616800e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-23 00:00:00, dtype: float64
# DATA Price
# Close               1.456200e+01
# High                1.472000e+01
# Low                 1.453400e+01
# Open                1.470000e+01
# Volume              3.641700e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-24 00:00:00, dtype: float64
# DATA Price
# Close               1.543670e+01
# High                1.591670e+01
# Low                 1.480000e+01
# Open                1.483730e+01
# Volume              1.750890e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-27 00:00:00, dtype: float64
# DATA Price
# Close               1.536530e+01
# High                1.570000e+01
# Low                 1.520200e+01
# Open                1.565000e+01
# Volume              9.128100e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-28 00:00:00, dtype: float64
# DATA Price
# Close               1.549670e+01
# High                1.566470e+01
# Low                 1.517530e+01
# Open                1.533670e+01
# Volume              5.904150e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-29 00:00:00, dtype: float64
# DATA Price
# Close               1.507000e+01
# High                1.552600e+01
# Low                 1.501130e+01
# Open                1.535930e+01
# Volume              5.867850e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-04-30 00:00:00, dtype: float64
# DATA Price
# Close               1.506870e+01
# High                1.545130e+01
# Low                 1.469400e+01
# Open                1.532930e+01
# Volume              7.922550e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-01 00:00:00, dtype: float64
# DATA Price
# Close               1.536730e+01
# High                1.564870e+01
# Low                 1.514070e+01
# Open                1.521200e+01
# Volume              6.651900e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-04 00:00:00, dtype: float64
# DATA Price
# Close               1.553000e+01
# High                1.596670e+01
# Low                 1.527530e+01
# Open                1.585070e+01
# Volume              8.695350e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-05 00:00:00, dtype: float64
# DATA Price
# Close               1.536200e+01
# High                1.563130e+01
# Low                 1.521330e+01
# Open                1.560670e+01
# Volume              7.906350e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-06 00:00:00, dtype: float64
# DATA Price
# Close               1.578670e+01
# High                1.583200e+01
# Low                 1.468330e+01
# Open                1.473330e+01
# Volume              1.418385e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-07 00:00:00, dtype: float64
# DATA Price
# Close               1.577400e+01
# High                1.589400e+01
# Low                 1.558000e+01
# Open                1.573270e+01
# Volume              7.002300e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-08 00:00:00, dtype: float64
# DATA Price
# Close               1.596600e+01
# High                1.619200e+01
# Low                 1.568730e+01
# Open                1.575270e+01
# Volume              8.508450e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-11 00:00:00, dtype: float64
# DATA Price
# Close               1.631600e+01
# High                1.642330e+01
# Low                 1.587930e+01
# Open                1.600730e+01
# Volume              9.545100e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-12 00:00:00, dtype: float64
# DATA Price
# Close               1.621200e+01
# High                1.655330e+01
# Low                 1.615000e+01
# Open                1.650730e+01
# Volume              8.160300e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-13 00:00:00, dtype: float64
# DATA Price
# Close               1.627330e+01
# High                1.632600e+01
# Low                 1.608330e+01
# Open                1.632130e+01
# Volume              4.343850e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-14 00:00:00, dtype: float64
# DATA Price
# Close               1.658930e+01
# High                1.662670e+01
# Low                 1.616670e+01
# Open                1.626200e+01
# Volume              6.791400e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-15 00:00:00, dtype: float64
# DATA Price
# Close               1.658330e+01
# High                1.666000e+01
# Low                 1.640000e+01
# Open                1.646670e+01
# Volume              5.029800e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-18 00:00:00, dtype: float64
# DATA Price
# Close               1.647600e+01
# High                1.673330e+01
# Low                 1.641000e+01
# Open                1.656200e+01
# Volume              5.511300e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-19 00:00:00, dtype: float64
# DATA Price
# Close               1.629000e+01
# High                1.651600e+01
# Low                 1.609130e+01
# Open                1.647530e+01
# Volume              5.633400e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-20 00:00:00, dtype: float64
# DATA Price
# Close               1.637470e+01
# High                1.644130e+01
# Low                 1.615730e+01
# Open                1.620200e+01
# Volume              2.955900e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-21 00:00:00, dtype: float64
# DATA Price
# Close               1.651530e+01
# High                1.657330e+01
# Low                 1.633400e+01
# Open                1.635870e+01
# Volume              3.334650e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-22 00:00:00, dtype: float64
# DATA Price
# Close               1.649730e+01
# High                1.680000e+01
# Low                 1.643330e+01
# Open                1.651200e+01
# Volume              5.248050e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-26 00:00:00, dtype: float64
# DATA Price
# Close               1.649530e+01
# High                1.663330e+01
# Low                 1.637000e+01
# Open                1.656730e+01
# Volume              5.112300e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-27 00:00:00, dtype: float64
# DATA Price
# Close               1.676330e+01
# High                1.678670e+01
# Low                 1.633670e+01
# Open                1.646870e+01
# Volume              5.470950e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-28 00:00:00, dtype: float64
# DATA Price
# Close               1.672000e+01
# High                1.685800e+01
# Low                 1.662870e+01
# Open                1.673330e+01
# Volume              5.683950e+07
# Entry_Signal       -1.000000e+00
# Exit_Signal         1.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       5.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-05-29 00:00:00, dtype: float64
# OPENING SHORT
# DATA Price
# Close               1.663000e+01
# High                1.677330e+01
# Low                 1.649800e+01
# Open                1.676070e+01
# Volume              3.757650e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-01 00:00:00, dtype: float64
# DATA Price
# Close               1.655670e+01
# High                1.662670e+01
# Low                 1.642000e+01
# Open                1.659470e+01
# Volume              3.202200e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-02 00:00:00, dtype: float64
# DATA Price
# Close               1.659930e+01
# High                1.671470e+01
# Low                 1.646730e+01
# Open                1.654670e+01
# Volume              2.672250e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-03 00:00:00, dtype: float64
# DATA Price
# Close               1.639470e+01
# High                1.662000e+01
# Low                 1.638070e+01
# Open                1.650000e+01
# Volume              3.680400e+07
# Entry_Signal        1.000000e+00
# Exit_Signal        -1.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       5.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-04 00:00:00, dtype: float64
# OPENING LONG
# DATA Price
# Close               1.660930e+01
# High                1.664670e+01
# Low                 1.637870e+01
# Open                1.640000e+01
# Volume              4.533000e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-05 00:00:00, dtype: float64
# DATA Price
# Close               1.708600e+01
# High                1.725000e+01
# Low                 1.668730e+01
# Open                1.672330e+01
# Volume              7.525500e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-08 00:00:00, dtype: float64
# DATA Price
# Close               1.706670e+01
# High                1.718270e+01
# Low                 1.694270e+01
# Open                1.702670e+01
# Volume              3.916650e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-09 00:00:00, dtype: float64
# DATA Price
# Close               1.671330e+01
# High                1.693330e+01
# Low                 1.656670e+01
# Open                1.679330e+01
# Volume              5.181750e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-10 00:00:00, dtype: float64
# DATA Price
# Close               1.676070e+01
# High                1.695800e+01
# Low                 1.669530e+01
# Open                1.688400e+01
# Volume              3.066150e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-11 00:00:00, dtype: float64
# DATA Price
# Close               1.671270e+01
# High                1.689730e+01
# Low                 1.668070e+01
# Open                1.668070e+01
# Volume              2.133450e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-12 00:00:00, dtype: float64
# DATA Price
# Close               1.669200e+01
# High                1.675200e+01
# Low                 1.640070e+01
# Open                1.664670e+01
# Volume              3.279300e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-15 00:00:00, dtype: float64
# DATA Price
# Close               1.687470e+01
# High                1.689600e+01
# Low                 1.660670e+01
# Open                1.667530e+01
# Volume              2.977050e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-16 00:00:00, dtype: float64
# DATA Price
# Close               1.736070e+01
# High                1.762400e+01
# Low                 1.680130e+01
# Open                1.681130e+01
# Volume              8.269350e+07
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2015-06-17 00:00:00, dtype: float64
# DATA Price
# Close               1.745930e+01
# High                1.756400e+01
# Low                 1.733470e+01
# ...
# High                3.299800e+02
# Low                 3.103700e+02
# Open                3.276900e+02
# Volume              1.207261e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-11-14 00:00:00, dtype: float64
# DATA Price
# Close               3.207200e+02
# High                3.246800e+02
# Low                 3.092200e+02
# Open                3.105700e+02
# Volume              1.144403e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-11-15 00:00:00, dtype: float64
# DATA Price
# Close               3.387400e+02
# High                3.485500e+02
# Low                 3.300100e+02
# Open                3.407300e+02
# Volume              1.260856e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-11-18 00:00:00, dtype: float64
# DATA Price
# Close                    346.00
# High                     347.38
# Low                      332.75
# Open                     335.76
# Volume              88852500.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-11-19 00:00:00, dtype: float64
# DATA Price
# Close                    342.03
# High                     346.60
# Low                      334.30
# Open                     345.00
# Volume              66340700.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-11-20 00:00:00, dtype: float64
# DATA Price
# Close                    339.64
# High                     347.99
# Low                      335.28
# Open                     343.81
# Volume              58011700.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-11-21 00:00:00, dtype: float64
# DATA Price
# Close                    352.56
# High                     361.53
# Low                      337.70
# Open                     341.09
# Volume              89140700.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-11-22 00:00:00, dtype: float64
# DATA Price
# Close                    338.59
# High                     361.93
# Low                      338.20
# Open                     360.14
# Volume              95890900.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-11-25 00:00:00, dtype: float64
# DATA Price
# Close                    338.23
# High                     346.96
# Low                      335.66
# Open                     341.00
# Volume              62295900.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-11-26 00:00:00, dtype: float64
# DATA Price
# Close                    332.89
# High                     342.55
# Low                      326.59
# Open                     341.80
# Volume              57896400.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-11-27 00:00:00, dtype: float64
# DATA Price
# Close                    345.16
# High                     345.45
# Low                      334.65
# Open                     336.08
# Volume              37167600.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-11-29 00:00:00, dtype: float64
# DATA Price
# Close                    357.09
# High                     360.00
# Low                      351.15
# Open                     352.38
# Volume              77986500.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-02 00:00:00, dtype: float64
# DATA Price
# Close                    351.42
# High                     355.69
# Low                      348.20
# Open                     351.80
# Volume              58267200.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-03 00:00:00, dtype: float64
# DATA Price
# Close                    357.93
# High                     358.10
# Low                      348.60
# Open                     353.00
# Volume              50810900.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-04 00:00:00, dtype: float64
# DATA Price
# Close                    369.49
# High                     375.43
# Low                      359.50
# Open                     359.87
# Volume              81403600.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-05 00:00:00, dtype: float64
# DATA Price
# Close                    389.22
# High                     389.49
# Low                      370.80
# Open                     377.42
# Volume              81455800.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-06 00:00:00, dtype: float64
# DATA Price
# Close                    389.79
# High                     404.80
# Low                      378.01
# Open                     397.61
# Volume              96359200.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-09 00:00:00, dtype: float64
# DATA Price
# Close                    400.99
# High                     409.73
# Low                      390.85
# Open                     392.68
# Volume              97563600.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-10 00:00:00, dtype: float64
# DATA Price
# Close               4.247700e+02
# High                4.248800e+02
# Low                 4.023800e+02
# Open                4.097000e+02
# Volume              1.042876e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-12-11 00:00:00, dtype: float64
# DATA Price
# Close                    418.10
# High                     429.30
# Low                      415.00
# Open                     424.84
# Volume              87752200.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-12 00:00:00, dtype: float64
# DATA Price
# Close                    436.23
# High                     436.30
# Low                      415.71
# Open                     420.00
# Volume              89000200.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-13 00:00:00, dtype: float64
# DATA Price
# Close               4.630200e+02
# High                4.631900e+02
# Low                 4.361500e+02
# Open                4.410900e+02
# Volume              1.140838e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-12-16 00:00:00, dtype: float64
# DATA Price
# Close               4.798600e+02
# High                4.839900e+02
# Low                 4.575100e+02
# Open                4.759000e+02
# Volume              1.312230e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-12-17 00:00:00, dtype: float64
# DATA Price
# Close               4.401300e+02
# High                4.885400e+02
# Low                 4.270100e+02
# Open                4.665000e+02
# Volume              1.493408e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-12-18 00:00:00, dtype: float64
# DATA Price
# Close               4.361700e+02
# High                4.563600e+02
# Low                 4.200200e+02
# Open                4.518800e+02
# Volume              1.185661e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-12-19 00:00:00, dtype: float64
# DATA Price
# Close               4.210600e+02
# High                4.470800e+02
# Low                 4.176400e+02
# Open                4.255100e+02
# Volume              1.322162e+08
# Entry_Signal        2.000000e+00
# Exit_Signal         2.000000e+00
# Edit_Signal         2.000000e+00
# Signal_Volume       0.000000e+00
# Signal_Stop_Loss    0.000000e+00
# Signal_Limit        0.000000e+00
# Name: 2024-12-20 00:00:00, dtype: float64
# DATA Price
# Close                    430.60
# High                     434.51
# Low                      415.41
# Open                     431.00
# Volume              72698100.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-23 00:00:00, dtype: float64
# DATA Price
# Close                    462.28
# High                     462.78
# Low                      435.14
# Open                     435.90
# Volume              59551800.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-24 00:00:00, dtype: float64
# DATA Price
# Close                    454.13
# High                     465.33
# Low                      451.02
# Open                     465.16
# Volume              76366400.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-26 00:00:00, dtype: float64
# DATA Price
# Close                    431.66
# High                     450.00
# Low                      426.50
# Open                     449.52
# Volume              82666800.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-27 00:00:00, dtype: float64
# DATA Price
# Close                    417.41
# High                     427.00
# Low                      415.75
# Open                     419.40
# Volume              64941000.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-30 00:00:00, dtype: float64
# DATA Price
# Close                    403.84
# High                     427.93
# Low                      402.54
# Open                     423.79
# Volume              76825100.00
# Entry_Signal               2.00
# Exit_Signal                2.00
# Edit_Signal                2.00
# Signal_Volume              0.00
# Signal_Stop_Loss           0.00
# Signal_Limit               0.00
# Name: 2024-12-31 00:00:00, dtype: float64
#      State Order_Type Volume            Open_Time Open_Price  \
# 0   Closed       Sell      5  2015-05-29 00:00:00    16.7333
# 1   Closed        Buy      5  2015-06-04 00:00:00       16.5
# 2   Closed       Sell      5  2016-01-22 00:00:00    13.6533
# 3   Closed        Buy      5  2016-07-25 00:00:00     14.818
# 4   Closed       Sell      5  2016-08-29 00:00:00    14.6767
# 5   Closed        Buy      5  2017-03-09 00:00:00    16.5087
# 6   Closed       Sell      5  2018-07-16 00:00:00    20.7807
# 7   Closed        Buy      5  2019-03-13 00:00:00    18.9267
# 8   Closed       Sell      5  2019-03-29 00:00:00      18.58
# 9   Closed        Buy      5  2020-01-02 00:00:00       28.3
# 10  Closed       Sell      5  2022-08-30 00:00:00     287.87
# 11  Closed        Buy      5  2023-09-19 00:00:00     264.35
# 12  Closed       Sell      5  2024-03-12 00:00:00     177.77
# 13  Closed        Buy      5  2024-10-09 00:00:00     243.82
#
#              Close_Time Close_Price Stop_Loss Limit Info   Profit Commission  \
# 0   2015-06-04 00:00:00        16.5       0.0   0.0          1.17       -0.0
# 1   2016-01-22 00:00:00     13.6533       0.0   0.0        -14.23       -0.0
# 2   2016-07-25 00:00:00      14.818       0.0   0.0         -5.82       -0.0
# 3   2016-08-29 00:00:00     14.6767       0.0   0.0         -0.71       -0.0
# 4   2017-03-09 00:00:00     16.5087       0.0   0.0         -9.16       -0.0
# 5   2018-07-16 00:00:00     20.7807       0.0   0.0         21.36       -0.0
# 6   2019-03-13 00:00:00     18.9267       0.0   0.0          9.27       -0.0
# 7   2019-03-29 00:00:00       18.58       0.0   0.0         -1.73       -0.0
# 8   2020-01-02 00:00:00        28.3       0.0   0.0        -48.60       -0.0
# 9   2022-08-30 00:00:00      287.87       0.0   0.0       1297.85       -0.0
# 10  2023-09-19 00:00:00      264.35       0.0   0.0        117.60       -0.0
# 11  2024-03-12 00:00:00      177.77       0.0   0.0       -432.90       -0.0
# 12  2024-10-09 00:00:00      243.82       0.0   0.0       -330.25       -0.0
# 13  2024-12-31 00:00:00      403.84       0.0   0.0        800.10       -0.0
#
#    Net_Profit Cumulative_Profit    Balance Drawdown
# 0        1.17              1.17  100001.17      NaN
# 1      -14.23            -13.06   99986.94      NaN
# 2       -5.82            -18.88   99981.12      NaN
# 3       -0.71            -19.59   99980.41      NaN
# 4       -9.16            -28.75   99971.25      NaN
# 5       21.36             -7.39   99992.61      NaN
# 6        9.27              1.88  100001.88      NaN
# 7       -1.73              0.15  100000.15      NaN
# 8       -48.6            -48.45   99951.55      NaN
# 9     1297.85            1249.4   101249.4      NaN
# 10      117.6            1367.0   101367.0      NaN
# 11     -432.9             934.1   100934.1      NaN
# 12    -330.25            603.85  100603.85      NaN
# 13      800.1           1403.95  101403.95      NaN

# %%
bt.evaluate_backtest()
# Out:
# RESULTS
# ========================================
# Biggest Win: 1297.85 USD
# Biggest Loss: -432.90 USD
#      State Order_Type Volume            Open_Time Open_Price  \
# 0   Closed       Sell      5  2015-05-29 00:00:00    16.7333
# 5   Closed        Buy      5  2017-03-09 00:00:00    16.5087
# 6   Closed       Sell      5  2018-07-16 00:00:00    20.7807
# 9   Closed        Buy      5  2020-01-02 00:00:00       28.3
# 10  Closed       Sell      5  2022-08-30 00:00:00     287.87
# 13  Closed        Buy      5  2024-10-09 00:00:00     243.82
#
#              Close_Time Close_Price Stop_Loss Limit Info   Profit Commission  \
# 0   2015-06-04 00:00:00        16.5       0.0   0.0          1.17       -0.0
# 5   2018-07-16 00:00:00     20.7807       0.0   0.0         21.36       -0.0
# 6   2019-03-13 00:00:00     18.9267       0.0   0.0          9.27       -0.0
# 9   2022-08-30 00:00:00      287.87       0.0   0.0       1297.85       -0.0
# 10  2023-09-19 00:00:00      264.35       0.0   0.0        117.60       -0.0
# 13  2024-12-31 00:00:00      403.84       0.0   0.0        800.10       -0.0
#
#    Net_Profit Cumulative_Profit    Balance Drawdown
# 0        1.17              1.17  100001.17      NaN
# 5       21.36             -7.39   99992.61      NaN
# 6        9.27              1.88  100001.88      NaN
# 9     1297.85            1249.4   101249.4      NaN
# 10      117.6            1367.0   101367.0      NaN
# 13      800.1           1403.95  101403.95      NaN
#      State Order_Type Volume            Open_Time Open_Price  \
# 1   Closed        Buy      5  2015-06-04 00:00:00       16.5
# 2   Closed       Sell      5  2016-01-22 00:00:00    13.6533
# 3   Closed        Buy      5  2016-07-25 00:00:00     14.818
# 4   Closed       Sell      5  2016-08-29 00:00:00    14.6767
# 7   Closed        Buy      5  2019-03-13 00:00:00    18.9267
# 8   Closed       Sell      5  2019-03-29 00:00:00      18.58
# 11  Closed        Buy      5  2023-09-19 00:00:00     264.35
# 12  Closed       Sell      5  2024-03-12 00:00:00     177.77
#
#              Close_Time Close_Price Stop_Loss Limit Info  Profit Commission  \
# 1   2016-01-22 00:00:00     13.6533       0.0   0.0       -14.23       -0.0
# 2   2016-07-25 00:00:00      14.818       0.0   0.0        -5.82       -0.0
# 3   2016-08-29 00:00:00     14.6767       0.0   0.0        -0.71       -0.0
# 4   2017-03-09 00:00:00     16.5087       0.0   0.0        -9.16       -0.0
# 7   2019-03-29 00:00:00       18.58       0.0   0.0        -1.73       -0.0
# 8   2020-01-02 00:00:00        28.3       0.0   0.0       -48.60       -0.0
# 11  2024-03-12 00:00:00      177.77       0.0   0.0      -432.90       -0.0
# 12  2024-10-09 00:00:00      243.82       0.0   0.0      -330.25       -0.0
#
#    Net_Profit Cumulative_Profit    Balance Drawdown
# 1      -14.23            -13.06   99986.94      NaN
# 2       -5.82            -18.88   99981.12      NaN
# 3       -0.71            -19.59   99980.41      NaN
# 4       -9.16            -28.75   99971.25      NaN
# 7       -1.73              0.15  100000.15      NaN
# 8       -48.6            -48.45   99951.55      NaN
# 11     -432.9             934.1   100934.1      NaN
# 12    -330.25            603.85  100603.85      NaN
# Average Win: 374.56 USD
# Average Loss: -105.42 USD
# Total Winning Trades: 6
# Total Losing Trades: 8
# Win Rate: 42.86%
# Profit Factor: 2.66
# Risk-Reward Ratio: 3.55
#   Order_Type Net_Profit
# 0        Buy    1669.74
# 1       Sell    -265.79
# Maximum Drawdown: 763.15 USD
# Sharpe Ratio: 0.27
# Sortino Ratio: 0.05
# Total Net Profit: 1403.95 USD
# Final Balance: 101403.95 USD
# ========================================
# {'biggest_win': 1297.85,
#  'biggest_loss': -432.9,
#  'avg_win': np.float64(374.55833333333334),
#  'avg_loss': np.float64(-105.425),
#  'total_win_trades': 6,
#  'total_loss_trades': 8,
#  'win_rate': 42.857142857142854,
#  'gross_profit': 2247.35,
#  'gross_loss': 843.4,
#  'profit_factor': 2.664631254446289,
#  'risk_reward_ratio': np.float64(3.552841672595052),
#  'max_drawdown': 763.15,
#  'sharpe_ratio': np.float64(0.27488236338637206),
#  'sortino_ratio': np.float64(0.05187375965492509),
#  'total_net_profit': 1403.9499999999998,
#  'final_balance': 101403.95}

# %%
bt.visualize_backtest()

# %%
bt.export_to_json("crossover.json", "TSLA")
# Out:
# RESULTS
# ========================================
# Biggest Win: 1297.85 USD
# Biggest Loss: -432.90 USD
#      State Order_Type Volume            Open_Time Open_Price  \
# 0   Closed       Sell      5  2015-05-29 00:00:00    16.7333
# 5   Closed        Buy      5  2017-03-09 00:00:00    16.5087
# 6   Closed       Sell      5  2018-07-16 00:00:00    20.7807
# 9   Closed        Buy      5  2020-01-02 00:00:00       28.3
# 10  Closed       Sell      5  2022-08-30 00:00:00     287.87
# 13  Closed        Buy      5  2024-10-09 00:00:00     243.82
#
#              Close_Time Close_Price Stop_Loss Limit Info   Profit Commission  \
# 0   2015-06-04 00:00:00        16.5       0.0   0.0          1.17       -0.0
# 5   2018-07-16 00:00:00     20.7807       0.0   0.0         21.36       -0.0
# 6   2019-03-13 00:00:00     18.9267       0.0   0.0          9.27       -0.0
# 9   2022-08-30 00:00:00      287.87       0.0   0.0       1297.85       -0.0
# 10  2023-09-19 00:00:00      264.35       0.0   0.0        117.60       -0.0
# 13  2024-12-31 00:00:00      403.84       0.0   0.0        800.10       -0.0
#
#    Net_Profit Cumulative_Profit    Balance Drawdown
# 0        1.17              1.17  100001.17      0.0
# 5       21.36             -7.39   99992.61     8.56
# 6        9.27              1.88  100001.88      0.0
# 9     1297.85            1249.4   101249.4      0.0
# 10      117.6            1367.0   101367.0      0.0
# 13      800.1           1403.95  101403.95      0.0
#      State Order_Type Volume            Open_Time Open_Price  \
# 1   Closed        Buy      5  2015-06-04 00:00:00       16.5
# 2   Closed       Sell      5  2016-01-22 00:00:00    13.6533
# 3   Closed        Buy      5  2016-07-25 00:00:00     14.818
# 4   Closed       Sell      5  2016-08-29 00:00:00    14.6767
# 7   Closed        Buy      5  2019-03-13 00:00:00    18.9267
# 8   Closed       Sell      5  2019-03-29 00:00:00      18.58
# 11  Closed        Buy      5  2023-09-19 00:00:00     264.35
# 12  Closed       Sell      5  2024-03-12 00:00:00     177.77
#
#              Close_Time Close_Price Stop_Loss Limit Info  Profit Commission  \
# 1   2016-01-22 00:00:00     13.6533       0.0   0.0       -14.23       -0.0
# 2   2016-07-25 00:00:00      14.818       0.0   0.0        -5.82       -0.0
# 3   2016-08-29 00:00:00     14.6767       0.0   0.0        -0.71       -0.0
# 4   2017-03-09 00:00:00     16.5087       0.0   0.0        -9.16       -0.0
# 7   2019-03-29 00:00:00       18.58       0.0   0.0        -1.73       -0.0
# 8   2020-01-02 00:00:00        28.3       0.0   0.0       -48.60       -0.0
# 11  2024-03-12 00:00:00      177.77       0.0   0.0      -432.90       -0.0
# 12  2024-10-09 00:00:00      243.82       0.0   0.0      -330.25       -0.0
#
#    Net_Profit Cumulative_Profit    Balance Drawdown
# 1      -14.23            -13.06   99986.94    14.23
# 2       -5.82            -18.88   99981.12    20.05
# 3       -0.71            -19.59   99980.41    20.76
# 4       -9.16            -28.75   99971.25    29.92
# 7       -1.73              0.15  100000.15     1.73
# 8       -48.6            -48.45   99951.55    50.33
# 11     -432.9             934.1   100934.1    432.9
# 12    -330.25            603.85  100603.85   763.15
# Average Win: 374.56 USD
# Average Loss: -105.42 USD
# Total Winning Trades: 6
# Total Losing Trades: 8
# Win Rate: 42.86%
# Profit Factor: 2.66
# Risk-Reward Ratio: 3.55
#   Order_Type Net_Profit
# 0        Buy    1669.74
# 1       Sell    -265.79
# Maximum Drawdown: 763.15 USD
# Sharpe Ratio: 0.27
# Sortino Ratio: 0.05
# Total Net Profit: 1403.95 USD
# Final Balance: 101403.95 USD
# ========================================
# True
